# %% [markdown]
# # Metadata Preferences Explorations

# %%
import sys
import json

from qdrant_client import AsyncQdrantClient
from pathlib import Path
from typing import Optional, Sequence, List
from tqdm.asyncio import tqdm

# Add parent directory to path to import from implementation package
# Notebooks are in implementation/notebooks/, so we go up two levels to project root
sys.path.insert(0, str(Path().resolve().parent.parent))

from implementation.classes.movie import BaseMovie
from implementation.classes.enums import (
    EntityCategory, 
    Genre,
    MaturityRating,
    MetadataPreferenceName,
)
from db.vector_search import run_vector_search
from db.search import search
from db.vector_scoring import calculate_vector_scores
from db.metadata_scoring import create_metadata_scores
from db.postgres import pool
from db.redis import init_redis
from db.search import SearchCandidate
from implementation.llms.query_understanding_methods import extract_single_metadata_preference_async
from implementation.classes.languages import Language
from movie_ingestion.final_ingestion.ingest_movie import ingest_movie_to_qdrant, ingest_movies_to_qdrant_batched
from implementation.classes.schemas import (
    MetadataPreferencesResponse,
    DatePreference,
    DatePreferenceResult,
    NumericalPreference,
    NumericalPreferenceResult,
    GenreListPreference,
    GenreListPreferenceResult,
    LanguageListPreference,
    LanguageListPreferenceResult,
    WatchProvidersPreference,
    WatchProvidersPreferenceResult,
    MaturityPreference,
    MaturityPreferenceResult,
    PopularTrendingPreference,
    ReceptionPreference,
    MetadataFilters,
    BudgetSizePreference,
)
from implementation.classes.enums import (
    NumericalMatchOperation,
    DateMatchOperation,
    RatingMatchOperation,
    ReceptionType,
    StreamingAccessType,
    BudgetSize,
)
from implementation.misc.helpers import tokenize_title_phrase, create_watch_provider_offering_key
from db.qdrant import qdrant_client
from db.search import search
from db.postgres import pool
from db.lexical_search import lexical_search

# %%
# LOAD MOVIES

json_path = Path("../../saved_imdb_movies.json")
with open(json_path, "r", encoding="utf-8") as f:
    movies_data = json.load(f)

# Convert each dictionary to an IMDBMovie object
movies = [BaseMovie(**movie_dict) for movie_dict in movies_data]

for i, movie in enumerate(movies):
    print(f"{i}: {movie.title} ({movie.tmdb_id})")
# Out:
# 0: ferris bueller's day off (9377)
# 1: zootopia (269149)
# 2: school of rock (1584)
# 3: frozen (109445)
# 4: the princess bride (2493)
# 5: coco (354912)
# 6: klaus (508965)
# 7: up (14160)
# 8: mulan (10674)
# 9: shrek (808)
# 10: the year without a santa claus (13397)
# 11: mad max: fury road (76341)
# 12: raiders of the lost ark (85)
# 13: the dark knight (155)
# 14: john wick (245891)
# 15: captain america: the first avenger (1771)
# 16: spider-man: across the spider-verse (569094)
# 17: avengers: endgame (299534)
# 18: star wars (11)
# 19: harry potter and the philosopher's stone (671)
# 20: the lord of the rings: the fellowship of the ring (120)
# 21: gladiator (98)
# 22: inception (27205)
# 23: the matrix (603)
# 24: interstellar (157336)
# 25: blade runner 2049 (335984)
# 26: jurassic park (329)
# 27: arrival (329865)
# 28: hereditary (493922)
# 29: the shining (694)
# 30: insidious (49018)
# 31: terrifier 3 (1034541)
# 32: saw (176)
# 33: se7en (807)
# ...

# %%
search_candidates: List[SearchCandidate] = []
for movie in movies:
    search_candidates.append(SearchCandidate(movie_id=movie.tmdb_id, vector_score=0.0, lexical_score=0.0, metadata_score=0.0))
print(f"Created {len(search_candidates)} search candidates")
# Out:
# Created 50 search candidates

# %%
await pool.open()

# %%
await init_redis()

# %%
query = "Boat movies with leo dicaprio from the 2000s"

search_results = await search(
    query=query,
    metadata_filters=MetadataFilters(),
    qdrant_client=qdrant_client,
    vector_candidate_limit_original=10,
    vector_candidate_limit_subquery=10,
    vector_candidate_limit_anchor=10,
)

for results in search_results.candidates[:10]:
    movie = [m for m in movies if m.tmdb_id == results.movie_id][0]
    print(f"{movie.title} ({results.final_score})")
    print(f"  v ({results.vector_score}), l ({results.lexical_score}), m ({results.metadata_score})")
# Out:
# Subquery LLM returned relevant_subquery_text as None for narrative_techniques, skipping subquery search.
# Weight LLM returned not_relevant for plot_analysis, skipping original-query search.
# Subquery LLM returned relevant_subquery_text as None for reception, skipping subquery search.
# Subquery LLM returned relevant_subquery_text as None for plot_events, skipping subquery search.
# Weight LLM returned not_relevant for watch_context, skipping original-query search.
# Subquery LLM returned relevant_subquery_text as None for watch_context, skipping subquery search.
# Subquery LLM returned relevant_subquery_text as None for plot_analysis, skipping subquery search.
# Weight LLM returned not_relevant for narrative_techniques, skipping original-query search.
# Weight LLM returned not_relevant for reception, skipping original-query search.
# Weight LLM returned not_relevant for viewer_experience, skipping original-query search.
# ...

# %%
metadata_debug = search_results.debug.metadata_preferences_debug
channel_weights_debug = search_results.debug.channel_weights_debug
lexical_debug = search_results.debug.lexical_debug
vector_debug = search_results.debug.vector_debug
print(f"Time to generate metadata preferences: {metadata_debug.llm_generation_time_ms}ms")
print(f"Time to generate channel weights: {channel_weights_debug.llm_generation_time_ms}ms")
print(f"Time to generate lexical scores: {lexical_debug.llm_generation_time_ms}ms")
print(f"Time to generate vector scores: {vector_debug.wall_clock_ms}ms")
# Out:
# Time to generate metadata preferences: 1474.5808746665716ms
# Time to generate channel weights: 1265.7954171299934ms
# Time to generate lexical scores: 2146.164166741073ms
# Time to generate vector scores: 7292.39ms

# %%
preferences = MetadataPreferencesResponse(
    release_date_preference=DatePreference(
        result=None
    ),
    duration_preference=NumericalPreference(
        result=None
    ),
    genres_preference=GenreListPreference(
        result=None
    ),
    audio_languages_preference=LanguageListPreference(
        result=None
    ),
    watch_providers_preference=WatchProvidersPreference(
        result=None
    ),
    maturity_rating_preference=MaturityPreference(
        result=None
    ),
    reception_preference=ReceptionPreference(
        reception_type=ReceptionType.NO_PREFERENCE
    ),
    popular_trending_preference=PopularTrendingPreference(
        prefers_trending_movies=False,
        prefers_popular_movies=False
    ),
    budget_size_preference=BudgetSizePreference(
        budget_size=BudgetSize.SMALL
    )
)

scored_candidates = await create_metadata_scores(
    preferences=preferences,
    candidates=search_candidates
)

sorted_candidates = sorted(scored_candidates, key=lambda x: x.metadata_score, reverse=True)

for candidate in sorted_candidates:
    movie = [m for m in movies if m.tmdb_id == candidate.movie_id][0]
    print(f"{movie.title} ({movie.reception_score()}) {candidate.metadata_score}")
# Out:
# ferris bueller's day off (67.8) 1.0
# hereditary (81.39999999999999) 1.0
# insidious (58.4) 1.0
# terrifier 3 (62.0) 1.0
# saw (58.0) 1.0
# parasite (92.19999999999999) 1.0
# get out (82.2) 1.0
# american psycho (68.8) 1.0
# past lives (87.6) 1.0
# everything everywhere all at once (79.4) 1.0
# zootopia (78.8) 0.0
# school of rock (78.0) 0.0
# frozen (74.6) 0.0
# the princess bride (78.8) 0.0
# coco (82.2) 0.0
# klaus (71.8) 0.0
# up (86.0) 0.0
# mulan (74.0) 0.0
# shrek (82.0) 0.0
# the year without a santa claus (77.0) 0.0
# mad max: fury road (86.4) 0.0
# raiders of the lost ark (85.2) 0.0
# the dark knight (87.4) 0.0
# john wick (70.8) 0.0
# captain america: the first avenger (67.2) 0.0
# spider-man: across the spider-verse (85.6) 0.0
# avengers: endgame (80.4) 0.0
# star wars (88.4) 0.0
# harry potter and the philosopher's stone (69.8) 0.0
# the lord of the rings: the fellowship of the ring (90.8) 0.0
# gladiator (74.19999999999999) 0.0
# inception (79.6) 0.0
# ...

# %%
if not maturity_preferences.result:
    print("No maturity preference found")
else:
    maturity_enum = MaturityRating.from_string_with_default(maturity_preferences.result.rating)
    print(f"Maturity preference: {maturity_enum} ({maturity_preferences.result.match_operation})")
# Out:
# No maturity preference found

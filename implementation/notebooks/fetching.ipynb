# %%
import sys
import json
from pathlib import Path
from bs4 import BeautifulSoup

# Add parent directory to path to import from implementation package
# Notebooks are in implementation/notebooks/, so we go up two levels to project root
sys.path.insert(0, str(Path().resolve().parent.parent))

from implementation.gather_data import fetch_featured_reviews, fetch_main_page
from implementation.extract_website_data import extract_featured_reviews
from implementation.movie import IMDBMovie
from implementation.schemas import IMDBReviewTheme

# %%
# LOAD MOVIES

json_path = Path("../../saved_imdb_movies.json")
with open(json_path, "r", encoding="utf-8") as f:
    movies_data = json.load(f)

# Convert each dictionary to an IMDBMovie object
movies = [IMDBMovie(**movie_dict) for movie_dict in movies_data]

# %%
import concurrent.futures

def process_movie(movie):
    try:
        scraped_reviews = fetch_featured_reviews(movie.id)
        featured_reviews = extract_featured_reviews(scraped_reviews.text)
        movie.featured_reviews = featured_reviews
        return movie, scraped_reviews
    except Exception as e:
        print(f"Error processing movie {movie.id}: {e}")
        return None, None

fixed_movies = []
failed_movies = []
# Variable to hold the last scraped reviews, preserving behavior for subsequent cells
scraped_reviews = None

# Use ThreadPoolExecutor to fetch in parallel
with concurrent.futures.ThreadPoolExecutor(max_workers=5) as executor:
    # Map returns results in the order of the input iterable
    results = executor.map(process_movie, movies)
    
    for movie, reviews in results:
        if movie:
            fixed_movies.append(movie)
        else:
            failed_movies.append(movie)

if fixed_movies:
    with open("../../saved_imdb_movies.json", "w", encoding="utf-8") as f:
        json.dump([movie.model_dump() for movie in fixed_movies], f, indent=2, ensure_ascii=False)
if failed_movies:
    with open("../../failed_fetches.json", "w", encoding="utf-8") as f:
        json.dump([movie.model_dump() for movie in failed_movies], f, indent=2, ensure_ascii=False)

print(f"Successfully updated {len(fixed_movies)} movies with featured reviews")
print(f"Failed to update {len(failed_movies)} movies")
# Out:
# Successfully updated 50 movies with featured reviews
# Failed to update 0 movies
# /Users/michaelkeohane/Documents/movie-finder-rag/.venv/lib/python3.13/site-packages/pydantic/main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': '"Life moves ...#39;t changing at all.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Not just a c...a good, genuine laugh.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Recaptures "...u won&#39;t regret it.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'When teen mo... it great.  I love it!'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Take the "Da...r&#39;s Day Off&quot;.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Not just one... I die.<br/><br/>10/10'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'One Of A Kin...cultural significance.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Genuinely, I...it a higher rating....'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'An interesti...ally rather effective.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': "Ferris Buell...m. It&#39;s a classic!'}, input_type=dict])
#   return self.__pydantic_serializer__.to_python(
# /Users/michaelkeohane/Documents/movie-finder-rag/.venv/lib/python3.13/site-packages/pydantic/main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': '"I don\'t kn...p foster that message.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'One of the b...mans, look no further!'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': "Didn't expec...ich was beautiful btw.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Next level f...re doing and watch it.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'An entertain...><br/>Brilliant movie.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'One of the M...njoyable for all ages.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': "You certainl...dancing in the aisles.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Zootopia : T... by value of this movi'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Animal Magic...beasts that they are).'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Best Disney ...movie is just awesome!'}, input_type=dict])
#   return self.__pydantic_serializer__.to_python(
# /Users/michaelkeohane/Documents/movie-finder-rag/.venv/lib/python3.13/site-packages/pydantic/main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Unbelievably...an even take the kids!'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': "Jumpin' Jack...edy that truly ROCKS!!'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Jack Black k...in this movie as well.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': "Maybe it's n... &quot;G&quot; rating.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Better than ...etter than I expected.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'You are not ... away. Rock on! 8.5/10'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Jack Black G...u love rock and roll).'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Jack Black i...br/><br/>Overall: 9/10'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Black attack...s good enough for now.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'For Those ab...ut on something great.'}, input_type=dict])
#   return self.__pydantic_serializer__.to_python(
# /Users/michaelkeohane/Documents/movie-finder-rag/.venv/lib/python3.13/site-packages/pydantic/main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Fun and adve...stly never saw coming.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Definitely U... for the whole family.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Some People ...fect but I enjoyed it.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Message of t...it&#39;s a good movie.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Very Unique'...A true Disney classic.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'I like it, b... magnificent singing).'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'The director...between sad and funny.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Most Overrat...nt for the animation.)'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary':
'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Did I watch ... for sexual pleasure..'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Flippity-flo... Reasons to STAY AWAY.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Erotic?  Not... from start to finish.'}, input_type=dict])
#   return self.__pydantic_serializer__.to_python(
# /Users/michaelkeohane/Documents/movie-finder-rag/.venv/lib/python3.13/site-packages/pydantic/main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Fans of Poir...r he goes on vacation.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Visually stu...ped for a perfect 10!)'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': "You'll never...challenge for casting!'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Definitively...ory make little sense.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Average', 't... predictable and flat.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Too differen...stie&#39;s adaptation.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': "The Little E...enough good direction.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Unfortunatel...ution and a fun watch.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'A Nice Chang...reciate its greatness.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Sheer entert...d, classic whodunnit:)'}, input_type=dict])
#   return self.__pydantic_serializer__.to_python(
# /Users/michaelkeohane/Documents/movie-finder-rag/.venv/lib/python3.13/site-packages/pydantic/main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Felt Like I ...s).<br/><br/>Grade: A.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'best film of...verywhere all at once.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': "Don't do dru...a breath of fresh air.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Fantastic', ...n, and from the heart.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'The most ori...n and again and again.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'A Metaphor o... magic specks of time.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'The best aci...er blockbuster movies!'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'This is the ...n over so many people.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': "Absolute Stu...that&#39;s everything.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'It Seemed En...usted and unsatisfied.'}, input_type=dict])
#   return self.__pydantic_serializer__.to_python(
# /Users/michaelkeohane/Documents/movie-finder-rag/.venv/lib/python3.13/site-packages/pydantic/main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'A Delightful... twenties. Four stars.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Wildly creat...al and fabulous films.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Terrific!', ...ic comedy lately made.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Epic indeed'...in a theater near you.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': "Honestly, I ... felt weird sometimes.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Scott should...njoyable comedy drama.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Something un...at little bit special.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': "Edgar Wright...eekspeakmagazine.com).'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Great style'...verything is a sequel.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'I really wan...t make me look bitter.'}, input_type=dict])
#   return self.__pydantic_serializer__.to_python(
# /Users/michaelkeohane/Documents/movie-finder-rag/.venv/lib/python3.13/site-packages/pydantic/main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'A movie that...ing from 7/10 to 9/10.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'What we can ...e in movie references.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Great blend ...onged there all along.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'In praise of...k you know the answer.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Leslie Neils...ring: 4/10 Drugs: 5/10'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': "Even when yo...have missed the point.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Lots of sill...39;ll enjoy this one .'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Only Leslie ...orbidden Planet&quot;!'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': 'Absolutely r...d online on 7-30-2025.'}, input_type=dict])
#   PydanticSerializationUnexpectedValue(Expected `IMDBFeaturedReview` - serialized value may not be as expected [field_name='featured_reviews', input_value={'summary': "The Zucker's... of the 80&#39;s.  A++'}, input_type=dict])
#   return self.__pydantic_serializer__.to_python(

# %%
def _parse_next_data(soup: BeautifulSoup) -> dict:
    script = soup.find("script", id="__NEXT_DATA__", type="application/json")
    if not script or not script.string:
        return {}
    try:
        return json.loads(script.string)
    except json.JSONDecodeError:
        return {}

def _safe_get(obj, path, default=None):
    cur = obj
    for key in path:
        if isinstance(cur, dict) and key in cur:
            cur = cur[key]
        else:
            return default
    return cur

# %%
def get_movie_review_themes(movie_id: str) -> list[IMDBReviewTheme]:
    main_scrape = fetch_main_page(movie_id)

    main_html = main_scrape.text

    soup = BeautifulSoup(main_html, "html.parser")
    nd = _parse_next_data(soup)

    review_themes = _safe_get(nd, ['props', 'pageProps', 'mainColumnData', 'reviewSummary', 'themes'], []) or []

    parsed_review_themes = []
    for theme in review_themes:
        name = _safe_get(theme, ['label', 'value'], None)
        sentiment = _safe_get(theme, ['sentiment'], None)
        if name and sentiment:
            parsed_review_themes.append(IMDBReviewTheme(name=name.lower(), sentiment=sentiment.lower()))

    return parsed_review_themes

# %%
import concurrent.futures

def process_movie(movie):
    try:
        review_themes = get_movie_review_themes(movie.id)
        movie.review_themes = review_themes
        return movie, review_themes
    except Exception as e:
        print(f"Error processing movie {movie.id}: {e}")
        return None, None

fixed_movies = []
failed_movies = []
# Variable to hold the last scraped reviews, preserving behavior for subsequent cells
scraped_reviews = None

# Use ThreadPoolExecutor to fetch in parallel
with concurrent.futures.ThreadPoolExecutor(max_workers=5) as executor:
    # Map returns results in the order of the input iterable
    results = executor.map(process_movie, movies)
    
    for movie, reviews in results:
        if movie:
            fixed_movies.append(movie)
        else:
            failed_movies.append(movie)

if fixed_movies:
    with open("../../saved_imdb_movies.json", "w", encoding="utf-8") as f:
        json.dump([movie.model_dump() for movie in fixed_movies], f, indent=2, ensure_ascii=False)
if failed_movies:
    with open("../../failed_fetches.json", "w", encoding="utf-8") as f:
        json.dump([movie.model_dump() for movie in failed_movies], f, indent=2, ensure_ascii=False)

print(f"Successfully updated {len(fixed_movies)} movies with featured reviews")
print(f"Failed to update {len(failed_movies)} movies")
# Out:
# Successfully updated 50 movies with featured reviews
# Failed to update 0 movies

# %%
for movie in movies:
    print(movie.title)
    converted_themes = [str(theme) for theme in movie.review_themes]
    print("\n".join(converted_themes))
    print()
# Out:
# ferris bueller's day off
#
#
# zootopia
# Attribute: ambitious; audience reception: positive
# Attribute: character chemistry; audience reception: positive
# Attribute: character development; audience reception: positive
# Attribute: comedic brilliance; audience reception: positive
# Attribute: cultural diversity; audience reception: positive
# Attribute: inspirational; audience reception: positive
# Attribute: social commentary; audience reception: positive
# Attribute: social issues; audience reception: positive
# Attribute: visual artistry; audience reception: positive
# Attribute: world-building; audience reception: positive
#
# school of rock
#
#
# frozen
#
#
# the princess bride
# Attribute: action sequences; audience reception: positive
# Attribute: character development; audience reception: positive
# Attribute: charming; audience reception: positive
# Attribute: comedic brilliance; audience reception: positive
# Attribute: fantastical elements; audience reception: positive
# Attribute: generational appeal; audience reception: positive
# Attribute: great ensemble; audience reception: positive
# Attribute: iconic lines; audience reception: positive
# Attribute: nostalgic; audience reception: positive
# Attribute: romantic; audience reception: positive
#
# coco
# Attribute: animation style; audience reception: positive
# Attribute: authentic emotion; audience reception: positive
# Attribute: character development; audience reception: positive
# Attribute: comforting; audience reception: positive
# Attribute: emotional weight; audience reception: positive
# Attribute: family dynamics; audience reception: positive
# Attribute: generational appeal; audience reception: positive
# Attribute: heartfelt; audience reception: positive
# Attribute: musical score; audience reception: positive
# Attribute: visual spectacle; audience reception: positive
#
# klaus
# Attribute: animation style; audience reception: positive
# Attribute: authentic emotion; audience reception: positive
# Attribute: character development; audience reception: positive
# Attribute: comedic brilliance; audience reception: positive
# Attribute: family dynamics; audience reception: positive
# Attribute: friendship; audience reception: positive
# Attribute: heartfelt; audience reception: positive
# Attribute: inspirational; audience reception: positive
# Attribute: production design; audience reception: positive
#
# up
# Attribute: animation style; audience reception: positive
# Attribute: authentic emotion; audience reception: positive
# Attribute: character development; audience reception: positive
# Attribute: comedic brilliance; audience reception: positive
# Attribute: emotional weight; audience reception: positive
# Attribute: family dynamics; audience reception: positive
# Attribute: friendship; audience reception: positive
# Attribute: inspirational; audience reception: positive
#
# mulan
#
#
# shrek
#
#
# the year without a santa claus
#
#
# mad max: fury road
# Attribute: action sequences; audience reception: positive
# Attribute: cinematography; audience reception: positive
# Attribute: dystopian elements; audience reception: positive
# Attribute: practical effects; audience reception: positive
# Attribute: production design; audience reception: positive
# Attribute: stunts; audience reception: positive
# Attribute: technical achievement; audience reception: positive
# Attribute: thrilling; audience reception: positive
# Attribute: visual spectacle; audience reception: positive
# Attribute: character development; audience reception: neutral
#
# raiders of the lost ark
# Attribute: action sequences; audience reception: positive
# Attribute: comedic brilliance; audience reception: positive
# Attribute: iconic performance; audience reception: positive
# Attribute: iconic score; audience reception: positive
# Attribute: nostalgic; audience reception: positive
# Attribute: production design; audience reception: positive
# Attribute: thrilling; audience reception: positive
# Attribute: special effects; audience reception: neutral
# Attribute: character development; audience reception: negative
# Attribute: thin story; audience reception: negative
#
# the dark knight
# Attribute: action sequences; audience reception: positive
# Attribute: cinematography; audience reception: positive
# Attribute: direction; audience reception: positive
# Attribute: standout performance; audience reception: positive
# Attribute: adaptation; audience reception: neutral
# Attribute: dark tone; audience reception: neutral
# Attribute: philosophical elements; audience reception: neutral
# Attribute: character development; audience reception: negative
# Attribute: pacing; audience reception: negative
#
# john wick
# Attribute: action sequences; audience reception: positive
# Attribute: cinematography; audience reception: positive
# Attribute: direction; audience reception: positive
# Attribute: fight choreography; audience reception: positive
# Attribute: performance; audience reception: positive
# Attribute: soundtrack; audience reception: positive
# Attribute: worldbuilding; audience reception: positive
# Attribute: character development; audience reception: neutral
# Attribute: over-the-top; audience reception: neutral
# Attribute: thin story; audience reception: negative
#
# captain america: the first avenger
# Attribute: chemistry; audience reception: positive
# Attribute: courage; audience reception: positive
# Attribute: performance; audience reception: positive
# Attribute: action sequences; audience reception: neutral
# Attribute: adaptation; audience reception: neutral
# Attribute: character development; audience reception: neutral
# Attribute: romantic; audience reception: neutral
# Attribute: historical accuracy; audience reception: negative
# Attribute: pacing; audience reception: negative
#
# spider-man: across the spider-verse
# Attribute: action sequences; audience reception: positive
# Attribute: animation style; audience reception: positive
# Attribute: emotional stakes; audience reception: positive
# Attribute: soundtrack; audience reception: positive
# Attribute: technical achievement; audience reception: positive
# Attribute: visual innovation; audience reception: positive
# Attribute: character development; audience reception: neutral
# Attribute: family dynamics; audience reception: neutral
# Attribute: pacing; audience reception: negative
#
# avengers: endgame
# Attribute: action sequences; audience reception: positive
# Attribute: character development; audience reception: positive
# Attribute: emotional weight; audience reception: positive
# Attribute: nostalgic; audience reception: positive
# Attribute: satisfying ending; audience reception: positive
# Attribute: pacing; audience reception: negative
# Attribute: thin story; audience reception: negative
# Attribute: uneven quality; audience reception: negative
#
# star wars
# Attribute: generational appeal; audience reception: positive
# Attribute: production design; audience reception: positive
# Attribute: realism; audience reception: positive
# Attribute: special effects; audience reception: positive
# Attribute: worldbuilding; audience reception: positive
# Attribute: dubbing; audience reception: neutral
# Attribute: character development; audience reception: negative
# Attribute: derivative; audience reception: negative
# Attribute: dialogue; audience reception: negative
#
# harry potter and the philosopher's stone
# Attribute: chemistry; audience reception: positive
# Attribute: cinematography; audience reception: positive
# Attribute: fantastical elements; audience reception: positive
# Attribute: production design; audience reception: positive
# Attribute: set pieces; audience reception: positive
# Attribute: worldbuilding; audience reception: positive
# Attribute: adaptation; audience reception: neutral
# Attribute: character development; audience reception: neutral
# Attribute: performance; audience reception: neutral
#
# the lord of the rings: the fellowship of the ring
# Attribute: adaptation; audience reception: positive
# Attribute: ambitious; audience reception: positive
# Attribute: authentic emotion; audience reception: positive
# Attribute: character development; audience reception: positive
# Attribute: cinematography; audience reception: positive
# Attribute: epic; audience reception: positive
# Attribute: friendship; audience reception: positive
# Attribute: production design; audience reception: positive
# Attribute: special effects; audience reception: positive
# Attribute: worldbuilding; audience reception: positive
#
# gladiator
# Attribute: action sequences; audience reception: positive
# Attribute: cinematography; audience reception: positive
# Attribute: direction; audience reception: positive
# Attribute: epic; audience reception: positive
# Attribute: iconic performance; audience reception: positive
# Attribute: iconic score; audience reception: positive
# Attribute: visual spectacle; audience reception: positive
# Attribute: historical accuracy; audience reception: negative
#
# inception
# Attribute: dreamlike; audience reception: positive
# Attribute: iconic ending; audience reception: positive
# Attribute: special effects; audience reception: positive
# Attribute: thought-provoking; audience reception: positive
# Attribute: ambitious; audience reception: neutral
# Attribute: character development; audience reception: neutral
# Attribute: narrative complexity; audience reception: neutral
# Attribute: confusing; audience reception: negative
# Attribute: pacing; audience reception: negative
#
# the matrix
# Attribute: action sequences; audience reception: positive
# Attribute: cinematography; audience reception: positive
# Attribute: philosophical elements; audience reception: positive
# Attribute: special effects; audience reception: positive
# Attribute: thought-provoking; audience reception: positive
# Attribute: character development; audience reception: neutral
# Attribute: dystopian elements; audience reception: neutral
# Attribute: religious themes; audience reception: neutral
#
# interstellar
# Attribute: ambitious; audience reception: positive
# Attribute: cinematography; audience reception: positive
# Attribute: cosmic wonder; audience reception: positive
# Attribute: emotional stakes; audience reception: positive
# Attribute: family dynamics; audience reception: positive
# Attribute: scientific depth; audience reception: positive
# Attribute: soundtrack; audience reception: positive
# Attribute: thought-provoking; audience reception: positive
#
# blade runner 2049
# Attribute: atmospheric; audience reception: positive
# Attribute: cinematography; audience reception: positive
# Attribute: dystopian elements; audience reception: positive
# Attribute: identity; audience reception: positive
# Attribute: philosophical elements; audience reception: positive
# Attribute: visual spectacle; audience reception: positive
# Attribute: worldbuilding; audience reception: positive
# Attribute: soundtrack; audience reception: neutral
# Attribute: pacing; audience reception: negative
#
# jurassic park
# Attribute: creature design; audience reception: positive
# Attribute: direction; audience reception: positive
# Attribute: generational appeal; audience reception: positive
# Attribute: iconic score; audience reception: positive
# Attribute: special effects; audience reception: positive
# Attribute: suspenseful; audience reception: positive
# Attribute: thrilling; audience reception: positive
# Attribute: visual spectacle; audience reception: positive
# Attribute: character development; audience reception: neutral
# Attribute: environmentalism; audience reception: neutral
#
# arrival
#
#
# hereditary
# Attribute: atmospheric; audience reception: positive
# Attribute: cinematography; audience reception: positive
# Attribute: direction; audience reception: positive
# Attribute: horror craft; audience reception: positive
# Attribute: performance; audience reception: positive
# Attribute: psychological depth; audience reception: positive
# Attribute: sound design; audience reception: positive
# Attribute: suspenseful; audience reception: positive
# Attribute: family dynamics; audience reception: neutral
# Attribute: supernatural themes; audience reception: neutral
#
# the shining
# Attribute: atmospheric; audience reception: positive
# Attribute: cinematography; audience reception: positive
# Attribute: iconic performance; audience reception: positive
# Attribute: production design; audience reception: positive
# Attribute: psychological depth; audience reception: positive
# Attribute: sound design; audience reception: positive
# Attribute: suspenseful; audience reception: positive
# Attribute: adaptation; audience reception: neutral
# Attribute: direction; audience reception: neutral
# Attribute: character development; audience reception: negative
#
# insidious
#
#
# terrifier 3
#
#
# saw
#
#
# se7en
# Attribute: atmospheric; audience reception: positive
# Attribute: cinematography; audience reception: positive
# Attribute: performance; audience reception: positive
# Attribute: suspenseful; audience reception: positive
# Attribute: thrilling; audience reception: positive
# Attribute: philosophical elements; audience reception: neutral
# Attribute: religious themes; audience reception: neutral
# Attribute: social commentary; audience reception: neutral
# Attribute: dark tone; audience reception: negative
#
# parasite
# Attribute: cinematography; audience reception: positive
# Attribute: dark humor; audience reception: positive
# Attribute: direction; audience reception: positive
# Attribute: dramatic tension; audience reception: positive
# Attribute: suspenseful; audience reception: positive
# Attribute: narrative complexity; audience reception: neutral
# Attribute: social commentary; audience reception: neutral
# Attribute: symbolism; audience reception: neutral
# Attribute: thought-provoking; audience reception: neutral
#
# get out
#
#
# american psycho
# Attribute: performance; audience reception: positive
# Attribute: production design; audience reception: positive
# Attribute: adaptation; audience reception: neutral
# Attribute: dark humor; audience reception: neutral
# Attribute: identity; audience reception: neutral
# Attribute: inner conflict; audience reception: neutral
# Attribute: psychological depth; audience reception: neutral
# Attribute: social commentary; audience reception: neutral
#
# fight club
# Attribute: allegorical elements; audience reception: positive
# Attribute: cinematography; audience reception: positive
# Attribute: direction; audience reception: positive
# Attribute: performance; audience reception: positive
# Attribute: psychological depth; audience reception: positive
# Attribute: social commentary; audience reception: positive
# Attribute: sound design; audience reception: positive
# Attribute: thought-provoking; audience reception: positive
# Attribute: narrative complexity; audience reception: neutral
#
# titanic
# Attribute: authentic emotion; audience reception: positive
# Attribute: chemistry; audience reception: positive
# Attribute: dramatic tension; audience reception: positive
# Attribute: production design; audience reception: positive
# Attribute: romantic; audience reception: positive
# Attribute: special effects; audience reception: positive
# Attribute: visual spectacle; audience reception: positive
# Attribute: historical accuracy; audience reception: neutral
# Attribute: performance; audience reception: neutral
# Attribute: thin story; audience reception: negative
#
# forrest gump
# Attribute: comedic brilliance; audience reception: positive
# Attribute: friendship; audience reception: positive
# Attribute: heartfelt; audience reception: positive
# Attribute: inspirational; audience reception: positive
# Attribute: nostalgic; audience reception: positive
# Attribute: personal growth; audience reception: positive
# Attribute: adaptation; audience reception: neutral
#
# past lives
#
#
# the pianist
# Attribute: atmospheric; audience reception: positive
# Attribute: cinematography; audience reception: positive
# Attribute: direction; audience reception: positive
# Attribute: emotional weight; audience reception: positive
# Attribute: historical accuracy; audience reception: positive
# Attribute: performance; audience reception: positive
# Attribute: production design; audience reception: positive
# Attribute: realism; audience reception: positive
# Attribute: survival; audience reception: positive
#
# the notebook
# Attribute: character development; audience reception: positive
# Attribute: chemistry; audience reception: positive
# Attribute: emotional stakes; audience reception: positive
# Attribute: heartfelt; audience reception: positive
# Attribute: nostalgic; audience reception: positive
# Attribute: romantic; audience reception: positive
# Attribute: suspenseful; audience reception: neutral
# Attribute: visual spectacle; audience reception: neutral
#
# 50 first dates
#
#
# leap year
#
#
# fifty shades of grey
# Attribute: cinematography; audience reception: positive
# Attribute: soundtrack; audience reception: positive
# Attribute: sexuality; audience reception: neutral
# Attribute: social commentary; audience reception: neutral
# Attribute: adaptation; audience reception: negative
# Attribute: character development; audience reception: negative
# Attribute: chemistry; audience reception: negative
# Attribute: dialogue; audience reception: negative
# Attribute: direction; audience reception: negative
# Attribute: thin story; audience reception: negative
#
# murder on the orient express
#
#
# everything everywhere all at once
# Attribute: action sequences; audience reception: positive
# Attribute: comedic brilliance; audience reception: positive
# Attribute: emotional weight; audience reception: positive
# Attribute: family dynamics; audience reception: positive
# Attribute: inspirational; audience reception: positive
# Attribute: visual spectacle; audience reception: positive
# Attribute: ambitious; audience reception: neutral
# Attribute: dark humor; audience reception: neutral
# Attribute: philosophical elements; audience reception: neutral
# Attribute: surreal; audience reception: neutral
#
# scott pilgrim vs. the world
# Attribute: adaptation; audience reception: positive
# Attribute: character development; audience reception: positive
# Attribute: comedic brilliance; audience reception: positive
# Attribute: generational appeal; audience reception: positive
# Attribute: great ensemble; audience reception: positive
# Attribute: killer soundtrack; audience reception: positive
# Attribute: kinetic style; audience reception: positive
# Attribute: nostalgic; audience reception: positive
# Attribute: visual innovation; audience reception: positive
#
# the naked gun: from the files of police squad!
# Attribute: comedic brilliance; audience reception: positive
# Attribute: comforting; audience reception: positive
# Attribute: generational appeal; audience reception: positive
# Attribute: great ensemble; audience reception: positive
# Attribute: iconic lines; audience reception: positive
# Attribute: iconic performance; audience reception: positive
# Attribute: nostalgic; audience reception: positive
# Attribute: physical comedy; audience reception: positive
# Attribute: rewatchable; audience reception: positive

# %%
movie_id = "tt11315808"

main_scrape = fetch_main_page(movie_id)

main_html = main_scrape.text

soup = BeautifulSoup(main_html, "html.parser")
nd = _parse_next_data(soup)

# %%
# REVIEW THEMES

review_themes = _safe_get(nd, ['props', 'pageProps', 'mainColumnData', 'reviewSummary', 'themes'], []) or []

parsed_review_themes = []
for theme in review_themes:
    name = _safe_get(theme, ['label', 'value'], None)
    sentiment = _safe_get(theme, ['sentiment'], None)
    if name and sentiment:
        parsed_review_themes.append(IMDBReviewTheme(name=name.lower(), sentiment=sentiment.lower()))

for theme in parsed_review_themes:
    print(theme)
# Out:
# Attribute: cinematography, audience reception: positive
# Attribute: performance, audience reception: positive
# Attribute: ambitious, audience reception: neutral
# Attribute: inner conflict, audience reception: neutral
# Attribute: psychological depth, audience reception: neutral
# Attribute: social commentary, audience reception: neutral
# Attribute: adaptation, audience reception: negative
# Attribute: character development, audience reception: negative
# Attribute: musical score, audience reception: negative
# Attribute: pacing, audience reception: negative

# %%
scraped_reviews.text

reviews_html = scraped_reviews.text

soup = BeautifulSoup(reviews_html, "html.parser")
nd = _parse_next_data(soup)

reviews_data = nd['props']['pageProps']['contentData']['reviews']

for review_object in reviews_data[:10]:
    review_data = review_object['review']
    summary = review_data['reviewSummary']
    text = review_data['reviewText']
    print(f"({summary}) \n{text}")
    print()
# Out:
# (A Parody That Stands The Test of Time!)
# I find it curious that IMDB lists this soley as an adventure fantasy film. It is, partially, but I&#39;ve always viewed it as an amazingly well done parody.<br/><br/>It pokes fun of the fairy tale tropes while at the same time paying tribute to the genre. All the exaggeration about true love, evil princes, and torture chambers is on point. Its a self aware movie that plays up to its its biggest strength, the characters.<br/><br/>Every character in the film is memorable, even down to the preist who only has a few lines. The casting and writing of these characters all came together and it really shows. You just cant help but wish Wallace Shawn survived longer so his loveable villian character could get a little more screentime.<br/><br/>All in all, you should give this film a chance. Its a hilarious yet family friend entertaining ride that still holds up. As you wishhhhh!
think any of them could have held their own with either Dread Pirate Roberts/Farm Boy Westley (Cary Elwes) or Inigo Montoya (Mandy Patinkin). Now there could have been some special effects involved there, but if so, it wasn&#39;t transparent. Those two put on quite a show.<br/><br/>The story also had a few pretty cool concepts like the shrieking eels and the Cliffs of Insanity. The Fire Swamp and the Lightning Sand were kind of original too. The convoluted turn of phrase that old Vizzini (Wallace Shawn) engaged in trying to outwit the Dread Pirate was pretty amusing, and if you try to keep up with it you&#39;ll be hopelessly lost, so best not even to try. It was also neat to see Andre the Giant in the film, one of the wrestling world&#39;s all time favorites. Interesting, but when he spoke he sounded kind of normal, unlike his in-character TV interviews where he had a much more guttural and heavily accented voice.<br/><br/>With all that going on, it&#39;s easy to forget that the Princess Bride tale is a story within a story, as a grandfather (Peter Falk) attempts to carry on a long family tradition of reading a favorite book to his grandson (Fred Savage). It doesn&#39;t sound very favorable at the outset with the romance and the &#39;eeeuw&#39; kissing, but the kid warms up to the story when it sounds like there will be some action and adventure. If I had to come up with a minor nit-pick, it seemed like the picture got a bit more slapstick in the final third of the movie. Otherwise the humor was well placed and I thought it made for fine family fare.

# %%
with open('./nd.json', "r", encoding="utf-8") as f:
    scrape_data = json.load(f)

featured_reviews = scrape_data['props']['pageProps']['mainColumnData']['featuredReviews']['edges']

print(len(featured_reviews))

for review in featured_reviews:
    summary = review['node']['summary']['originalText']
    text = review['node']['text']['originalText']['plaidHtml']
    print(f"({summary}) \n{text}")
    print()
# Out:
# 5
# (True Love Conquers All)
# Cary Elwes, Mandy Patinkin, and Robin Wright Penn star in this classic fairy tale entitled The Princess Bride. It is based on a novel by William Goldman, who also wrote the screenplay. Director Rob Reiner brings life to this story and effectively evokes the enchanting spirit of the witty 1973 novel.<br/><br/>The movie opens with a sick boy (Fred Savage) who receives a visit from his grandfather (Peter Falk) who intends to read to him from his favorite book. The boy is not exactly pleased to be distracted from his world of video games. However, his mood quickly changes as he and the viewer are transported to a place out of time. We are taken to Florin, a kingdom in an imaginary land, complete with dashing heroes, cowardly princes, rhyming giants, rodents of unusual size, fancy swordfights, and yes . . . even some kissing.<br/><br/>
# This fairy tale begins on a farm in the countryside. There lives a beautiful, young woman named Buttercup (Robin Wright Penn) who learns that &quot;as you wish&quot; really means &quot;I love you&quot; when she falls for her farmhand Westley (Cary Elwes). While trying to seek his fortune, Westley disappears at sea and becomes an apparent victim of the Dread Pirate Roberts. A few years later, Buttercup, who is now engaged to Prince Humperdinck (Chris Sarandon), is kidnapped by a trio of misfits, which includes brains--Vizzini (Wallace Shawn); brawn--Fezzik (André the Giant); and sword--Inigo Montoya (Mandy Patinkin). As they sail away toward the Cliffs of Insanity, they notice the pursuit of a man in black. Now begins the adventure . . . .<br/><br/>
# The central idea of The Princess Bride is that true love can conquer all. Throughout the movie, there are many hardships and trials that true love must endure. The movie keeps the viewer guessing until the very end whether or not there will be the classic fairy tale ending.<br/><br/>
# This movie is appealing to me because of the classic fairy tale style combined with the witty humor, well choreographed action sequences, and intense instances of suspense. The characters are well developed and all the actors give an amazing performance which adds to the overall appeal of the movie. The Princess Bride is easily one of my all time favorite movies.
